# %%
import requests
import unidecode

# %%
CITIES_URL = "https://raw.githubusercontent.com/hieudoanm/tablebase/master/json/world/cities.json"

response = requests.get(CITIES_URL, timeout= 10)
response_json = response.json()
names = list(map(lambda city: city.get("name"), response_json))
unidecoded_names = list(map(unidecode.unidecode, names))
unique_unidecoded_names = list(set(unidecoded_names))
unique_unidecoded_names.sort()

print(len(unique_unidecoded_names), unique_unidecoded_names)
# Out:
# 156668 ["'Abasan al Jadidah", "'Abasan al Kabirah", "'Abbasabad-e Qusheh", "'Abd Shahhadh Musa", "'Abud", "'Afak", "'Afrin", "'Afula 'Illit", "'Ahuimanu", "'Aiea", "'Ain Abid", "'Ain Benian", "'Ain Boucif", "'Ain Deheb", "'Ain Khalfoun", "'Ain Merane", "'Ain el Beida", "'Ain el Bell", "'Ain el Berd", "'Ain el Hadjar", "'Ain el Hadjel", "'Ain el Hammam", "'Ain el Melh", "'Ain el Turk", "'Ajab Shir", "'Ajjah", "'Ajjul", "'Ajlun", "'Alaqahdari Atghar", "'Alaqahdari Dishu", "'Alaqahdari Gelan", "'Alaqahdari Sarobi", "'Alaqahdari Shah Joy", "'Alaqahdari Yosuf Khel", "'Alaqahdari-ye Almar", "'Ali Khel", "'Ali Muhammad Khel", "'Ali Sabieh", "'Ali Sher 'Alaqahdari", "'Ali al Ahmad", "'Ali al Gharbi", "'Alwan Muhammad", "'Anabta", "'Anat al Qadimah", "'Anata", "'Anin", "'Anjarah", "'Anzah", "'Aqraba", "'Arab Hasan as Suhayl", "'Arab ar Rashaydah", "'Ariqah", "'Arrabah", "'Arranah", "'Ashub", "'Asirah al Qibliyah", "'Asirah ash Shamaliyah", "'Assal al Ward", "'Atarah", "'Attil", "'Awarta", "'Ayn 'Arik", "'Ayn 'Isa", "'Ayn Halaqim", "'Ayn Jannah", "'Ayn Sarah", "'Ayn Yabrud", "'Ayn al 'Arab", "'Ayn al Arnab", "'Ayn al Bayda", "'Ayn al Fijah", "'Ayn an Nasr", "'Ayn ash Sharqiyah", "'Aynabus", "'Ayy", "'Azazah", "'Azmut", "'Azriqam", "'Azzun", "'Eilabun", "'Ele'ele", "'En Boqeq", "'En Netafim", "'En Zetim", "'Ewa Beach", "'Ewa Gentry", "'Ewa Villages", "'Ezbet el-Auqat", "'Ibri", "'Ibwayn", "'Illar", "'Irbin", "'Izbat Abu 'Atwah", "'Izbat Nadi as Sayd", "'Izbat al Burj", "'Izra", "'Ohonua", "'Oma'o", "'Ud al Bayda'", "'Unabah", "'Uqayribat", "'Uqrat Safhah", "'Urif", "'Usayfirat", "'Ushaysh al Jahra'", "'Uzeir", "'s Gravenmoer", "'s-Gravenzande", "'s-Heerenberg", "'s-Hertogenbosch", "'t Hoeksken", "'t Hofke", "'t Zand", '(Pokharithok Bajar)', '-', '1 Decembrie', '23 August', '25 de Agosto', '25 de Mayo', '28 de Noviembre', '665 Site Colonia', '@hm@db@yli', 'A Caniza', 'A Coruna', 'A Dos Cunhados', 'A Dos Francos', 'A Estrada', 'A Guarda', 'A Mezquita', 'A Pobra do Brollon', 'A Pobra do Caraminal', 'A Ramallosa', 'A Rua', 'A Veiga', 'A Ver-O-Mar', 'A da Beja', 'A do Facao', 'A dos Cunhados', 'A i Afjord', 'AEro Kommune', 'AEroskobing', 'Aabenraa', 'Aabenraa Kommune', 'Aach', 'Aachen', 'Aadorf', 'Aalborg', 'Aalburg', 'Aalen', 'Aaley', 'Aalsmeer', 'Aalst', 'Aalten', 'Aalter', 'Aanekoski', 'Aanislag', 'Aarau', 'Aarberg', 'Aarburg', 'Aarle-Rixtel', 'Aars', 'Aarschot', 'Aartselaar', 'Aarwangen', 'Aasbuttel', 'Aasiaat', 'Aast', 'Aatal', 'Aawangen', 'Ab-e Kamari', 'Aba', "Aba as Su'ud", 'Abaakhuda', 'Ababuj', 'Abaca', 'Abacas', 'Abadan', 'Abade de Neiva', 'Abadeh', 'Abades', 'Abadia', 'Abadia dos Dourados', 'Abadiania', 'Abadin', 'Abadino', 'Abadou', 'Abadszalok', 'Abadzekhskaya', 'Abaete', 'Abaetetuba', 'Abagur', 'Abai', 'Abaigar', 'Abajas', 'Abak', 'Abakaliki', 'Abakan', 'Abalak', 'Abalos', 'Abaltzisketa', 'Aban', 'Abana', 'Abanades', 'Abancay', 'Abang', 'Abangay', 'Abanilla', 'Abano Terme', 'Abanto', 'Abanto Zierbena / Abanto y Ciervana', 'Abapo', 'Abaran', 'Abare', 'Abarzuza', 'Abasar', 'Abasha', 'Abashiri', 'Abasolo', 'Abasto', 'Abastumani', 'Abatia', 'Abatskoye', 'Abaujszanto', 'Abay', 'Abaza', 'Abbadia Cerreto', 'Abbadia Lariana', 'Abbadia San Salvatore', 'Abbadia di Stura', 'Abbans-Dessus', 'Abbaretz', 'Abbas Kili', 'Abbasanta', 'Abbateggio', 'Abbaye Saint-Benoit de Port-Valais', 'Abbendorf', 'Abbenrode', 'Abberode', 'Abbesbuttel', 'Abbeville', 'Abbeville County', 'Abbey', 'Abbey Dore', 'Abbey Wood', 'Abbeydorney', 'Abbeyfeale', 'Abbeylara', 'Abbeyleix', 'Abbeyshrule', 'Abbiategrasso', 'Abborrberget', 'Abbots Langley', 'Abbots Ripton', 'Abbotsford', 'Abbotskerswell', 'Abbottabad', 'Abbotts', 'Abbotts Ann', 'Abbottstown', 'Abda', 'Abdanan', 'Abdelmoumen', 'Abdet', 'Abdi', 'Abdon Batista', 'Abdrakhmanovo', 'Abdulino', 'Abdullahabad', 'Abdurahmoni Jomi', 'Abeche', 'Abegondo', 'Abeilhan', 'Abejales', 'Abejar', 'Abejera', 'Abejorral', 'Abela', 'Abelardo Luz', 'Abeleda', 'Abelenda', 'Abella de la Conca', 'Abenberg', 'Abengibre', 'Abengourou', 'A ...
